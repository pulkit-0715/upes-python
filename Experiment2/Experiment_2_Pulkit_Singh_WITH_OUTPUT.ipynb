# %% [markdown]
# # Experiment 2
#
# **Name:** Pulkit Singh
# **SAP ID:** 590022181
# **Batch:** B12
# ---

# %% [markdown]
# ## 1. Check whether the given number is divisible by 3 and 5

# %%
num=int(input("Enter number"))
print(f"Number Entered {num}")
if num%3==0 and num%5==0 :
    print("Divisible")
else:
    print("Not dvisible")
# Out:
# Number Entered 15
# Divisible

# %% [markdown]
# ## 2. Check whether a given number is multiple of five

# %%
num = int(input("Enter Number"))
print(f"Number Entered {num}")
if num % 5 == 0:
    print("Multiple of 5")
else:
    print("Not a multiple of 5")
# Out:
# Number Entered 15
# Multiple of 5

# %% [markdown]
# ## 3. Find the greatest among two numbers

# %%
a = int(input("Enter Number"))
b = int(input("Enter Number"))

print(f"Number Entered {a,b}")
if a > b:
    print("Greatest:", a)
elif b > a:
    print("Greatest:", b)
else:
    print("Numbers are equal")
# Out:
# Number Entered (13, 13)
# Numbers are equal

# %% [markdown]
# ## 4. Find the greatest among three numbers

# %%
a = int(input("Enter Number"))
b = int(input("Enter Number"))
c = int(input("Enter Number"))

print(f"Number Entered {a,b,c}")
if a > b and a > c:
    print("Greatest:", a)
elif b > a and b > c:
    print("Greatest:", b)
else:
    print("Greatest:", c)
# Out:
# Number Entered (13, 21, 14)
# Greatest: 21

# %% [markdown]
# ## 5. Check roots of quadratic equation

# %%
import math

a = float(input("Enter value of a"))
b = float(input("Enter value of b"))
c = float(input("Enter value of c"))

d = b*b - 4*a*c

if d > 0:
    r1 = (-b + math.sqrt(d)) / (2*a)
    r2 = (-b - math.sqrt(d)) / (2*a)
    print(r1)
    print(r2)
elif d == 0:
    r = -b / (2*a)
    print(r)
else:
    real = -b / (2*a)
    imag = math.sqrt(-d) / (2*a)
    print(real, "+",imag,"i")
    print(real, "-",imag,"i")
# Out:
# -0.42857142857142855 + 0.9035079029052513 i
# -0.42857142857142855 - 0.9035079029052513 i

# %% [markdown]
# ## 6. Check leap year

# %%
year = int(input("Enter year"))
print(f"Year entered {year}")
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Year entered 1990
# Not a Leap Year

# %% [markdown]
# ## 7. Display next date

# %%
def is_leap(y):
    if y % 4 == 0:
        if y % 100 == 0:
            if y % 400 == 0:
                return True   
            else:
                return False 
        else:
            return True      
    else:
        return False         

day = int(input("day="))
month = int(input("month="))
year = int(input("year="))

print(f"Date entered : {day}/{month}/{year}")

days_in_month = [ 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
if is_leap(year):
    days_in_month[2] = 29

day += 1

if day > days_in_month[month-1]:
    day = 1
    month += 1

if month > 12:
    month = 1
    year += 1

print(f"Next day: {day}/{month}/{year}")
# Out:
# Date entered : 31/12/1999
# Next day: 1/1/2000

# %% [markdown]
# ## 8. Student Grade Sheet

# %%
'''Print the grade sheet of a student for the given range of cgpa. Scan marks of
five subjects and calculate the percentage.'''

print(f"Sample Grade\n")
name=input("Enter Name ")
rn=int(input("Enter roll Number "))
sap_id=int(input("Enter SAPID "))
sem=int(input("Enter semester"))
crs=input("Enter Course ")

print(f"\nEnter subject marks")
pds=int(input("Marks in pds"))
python=pds=int(input("Marks in Python"))
chem=pds=int(input("Marks in Chemistry"))
eng=pds=int(input("Marks in English"))
phy=pds=int(input("Marks in Physics"))

print(f"Name: {name} \t Roll Number: {rn}\nSAPID: {sap_id}\t Semester: {sem}\n Course:{crs}")

per=(pds+python+chem+eng+phy)/5

print(f"\nPercentage{per:.2f}")

score=per/10
print(f"\nCGPA:{score:.2f}")

if 0 <= score <= 3.4:
    grade = "F"
elif 3.5 <= score <= 5.0:
    grade = "C+"
elif 5.1 <= score <= 6.0:
    grade = "B"
elif 6.1 <= score <= 7.0:
    grade = "B+"
elif 7.1 <= score <= 8.0:
    grade = "A"
elif 8.1 <= score <= 9.0:
    grade = "A+"
elif 9.1 <= score <= 10.0:
    grade = "O"
else:
    grade = "Invalid Score! Please enter a value between 0 and 10."

print(f"\nGRADE: {grade}")
# Out:
# Sample Grade
#
#
# Enter subject marks
# Name: Pulkit Singh 	 Roll Number: 590022181
# SAPID: 590022181	 Semester: 1
#  Course:Btech CS
#
# Percentage86.00
#
# CGPA:8.60
#
# GRADE: A+

# %% [markdown]
# ---
# **Submitted By:** Pulkit Singh
# **SAP ID:** 590022181
#
# **Github** https://github.com/pulkit-0715
